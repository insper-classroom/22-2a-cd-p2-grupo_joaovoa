# %%
import csv 
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Lendo e tranformando o csv em uma base de dados
life_exp = pd.read_csv("API_SP.DYN.LE00.IN_DS2_en_csv_v2_4700946.csv", sep=",",skiprows=4)
gdp = pd.read_csv("API_NY.GDP.MKTP.CD_DS2_en_csv_v2_4701247.csv", sep=",", skiprows=4)
gini = pd.read_csv("API_SI.POV.GINI_DS2_en_csv_v2_4701295.csv", sep=",", skiprows=4)
inflacao = pd.read_csv("API_FP.CPI.TOTL.ZG_DS2_en_csv_v2_4701153.csv", sep=",", skiprows=4)

# %%
# Definindomos países que vamos trabalhar
paises = ["United States", "Brazil", "Russian Federation", "India", "China", "South Africa", "Uruguay", "Venezuela", "Germany", "Denmark", "Netherlands", "Switzerland", "Italy", "France", "Sweden", "Portugal", "United Kingdom", "Belgium", "Japan", "Singapore","New Zealand"]
cores = ["blue", "green", "red","orange", "red", "green", "blue", "yellow", "black", "red", "orange", "pink", "blue", "blue", "yellow", "violet", "blue", "yellow", "white", "violet", "purple" ]

# %%
# Filtrando os dados que desejamos utilizar no nosso trabalho
life_exp = life_exp.loc[:,["Country Name", "Country Code","2020"]]
gdp = gdp.loc[:,["Country Name", "Country Code","2018", "2019", "2020"]]
gini = gini.loc[:,["Country Name", "Country Code","2018"]]
inflacao = inflacao.loc[:,["Country Name", "Country Code","2018","2019","2020"]]

# %%
regioes = ["Europe","South America","Europe","Asia","Europe","Europe","Europe","Europe","Asia","Europe","Asia","Europe","Oceania","Europa", "Asia","Asia","Europe","South America","North America","Africa"]

# %%
# Filtrando nossas bases com base nos países que queremos trabalhar
life_exp = life_exp.loc[life_exp["Country Name"].isin(paises),:]
gdp = gdp.loc[gdp["Country Name"].isin(paises),:]
gini = gini.loc[gini["Country Name"].isin(paises),:]
inflacao = inflacao.loc[inflacao["Country Name"].isin(paises),:]


life_exp["Region"] = regioes
gdp["Region"] = regioes
gini["Region"] = regioes
inflacao["Region"] = regioes

# %%
life_exp.head(30)
# Out:
#            Country Name Country Code       2020         Region
# 17              Belgium          BEL  80.795122         Europe
# 29               Brazil          BRA  76.084000  South America
# 37          Switzerland          CHE  83.100000         Europe
# 40                China          CHN  77.097000           Asia
# 55              Germany          DEU  80.941463         Europe
# 58              Denmark          DNK  81.551220         Europe
# 77               France          FRA  82.175610         Europe
# 81       United Kingdom          GBR  80.902439         Europe
# 109               India          IND  69.887000           Asia
# 116               Italy          ITA  82.343902         Europe
# 119               Japan          JPN  84.615610           Asia
# 176         Netherlands          NLD  81.409756         Europe
# 180         New Zealand          NZL  82.056098        Oceania
# 194            Portugal          PRT  80.975610         Europa
# 202  Russian Federation          RUS  71.338780           Asia
# 208           Singapore          SGP  83.743902           Asia
# 223              Sweden          SWE  82.407317         Europe
# 250             Uruguay          URY  78.056000  South America
# 251       United States          USA  77.280488  North America
# 263        South Africa          ZAF  64.379000         Africa

# %%
gdp.head(30)
# Out:
#            Country Name Country Code          2018          2019  \
# 17              Belgium          BEL  5.433474e+11  5.353763e+11
# 29               Brazil          BRA  1.916934e+12  1.873288e+12
# 37          Switzerland          CHE  7.355393e+11  7.317674e+11
# 40                China          CHN  1.389482e+13  1.427994e+13
# 55              Germany          DEU  3.977289e+12  3.888327e+12
# 58              Denmark          DNK  3.568412e+11  3.475613e+11
# 77               France          FRA  2.790957e+12  2.728870e+12
# 81       United Kingdom          GBR  2.900791e+12  2.878674e+12
# 109               India          IND  2.702930e+12  2.831552e+12
# 116               Italy          ITA  2.091932e+12  2.011286e+12
# 119               Japan          JPN  5.037835e+12  5.123318e+12
# 176         Netherlands          NLD  9.140434e+11  9.101943e+11
# 180         New Zealand          NZL  2.119531e+11  2.134346e+11
# 194            Portugal          PRT  2.423131e+11  2.399869e+11
# 202  Russian Federation          RUS  1.657330e+12  1.693114e+12
# 208           Singapore          SGP  3.769981e+11  3.754727e+11
# 223              Sweden          SWE  5.554554e+11  5.338795e+11
# 250             Uruguay          URY  6.451504e+10  6.123115e+10
# 251       United States          USA  2.052716e+13  2.137257e+13
# 263        South Africa          ZAF  4.048421e+11  3.879346e+11
#
#              2020         Region
# 17   5.216769e+11         Europe
# 29   1.448566e+12  South America
# 37   7.522480e+11         Europe
# 40   1.468767e+13           Asia
# 55   3.846414e+12         Europe
# 58   3.560849e+11         Europe
# 77   2.630318e+12         Europe
# 81   2.756900e+12         Europe
# 109  2.667688e+12           Asia
# 116  1.892574e+12         Europe
# 119  5.040108e+12           Asia
# 176  9.138654e+11         Europe
# 180  2.117345e+11        Oceania
# 194  2.285392e+11         Europa
# 202  1.488322e+12           Asia
# 208  3.452959e+11           Asia
# 223  5.414872e+11         Europe
# 250  5.356076e+10  South America
# 251  2.089374e+13  North America
# 263  3.354421e+11         Africa

# %%
gini.head(35)
# Out:
#            Country Name Country Code  2018         Region
# 17              Belgium          BEL  27.2         Europe
# 29               Brazil          BRA  53.9  South America
# 37          Switzerland          CHE  33.1         Europe
# 40                China          CHN  38.5           Asia
# 55              Germany          DEU  31.7         Europe
# 58              Denmark          DNK  28.2         Europe
# 77               France          FRA  32.4         Europe
# 81       United Kingdom          GBR   NaN         Europe
# 109               India          IND  34.6           Asia
# 116               Italy          ITA  35.2         Europe
# 119               Japan          JPN   NaN           Asia
# 176         Netherlands          NLD  28.1         Europe
# 180         New Zealand          NZL   NaN        Oceania
# 194            Portugal          PRT  33.5         Europa
# 202  Russian Federation          RUS  37.5           Asia
# 208           Singapore          SGP   NaN           Asia
# 223              Sweden          SWE  30.0         Europe
# 250             Uruguay          URY  39.7  South America
# 251       United States          USA  41.4  North America
# 263        South Africa          ZAF   NaN         Africa

# %%
inflacao.head(30)
# Out:
#            Country Name Country Code      2018      2019      2020  \
# 17              Belgium          BEL  2.053165  1.436820  0.740792
# 29               Brazil          BRA  3.664850  3.732976  3.211768
# 37          Switzerland          CHE  0.936335  0.362886 -0.725875
# 40                China          CHN  2.074790  2.899234  2.419422
# 55              Germany          DEU  1.732168  1.445667  0.506690
# 58              Denmark          DNK  0.813609  0.758132  0.420712
# 77               France          FRA  1.850815  1.108255  0.476499
# 81       United Kingdom          GBR  2.292840  1.738105  0.989487
# 109               India          IND  3.938826  3.729506  6.623437
# 116               Italy          ITA  1.137488  0.611247 -0.137708
# 119               Japan          JPN  0.989095  0.468776 -0.024996
# 176         Netherlands          NLD  1.703498  2.633699  1.272460
# 180         New Zealand          NZL  1.598297  1.619632  1.714562
# 194            Portugal          PRT  0.993716  0.338178 -0.012438
# 202  Russian Federation          RUS  2.878297  4.470367  3.381659
# 208           Singapore          SGP  0.438620  0.565261 -0.181917
# 223              Sweden          SWE  1.953535  1.784151  0.497367
# 250             Uruguay          URY  7.606534  7.881989  9.756406
# 251       United States          USA  2.442583  1.812210  1.233584
# 263        South Africa          ZAF  4.517165  4.120246  3.210036
#
#             Region
# 17          Europe
# 29   South America
# 37          Europe
# 40            Asia
# 55          Europe
# 58          Europe
# 77          Europe
# 81          Europe
# 109           Asia
# 116         Europe
# 119           Asia
# 176         Europe
# 180        Oceania
# 194         Europa
# 202           Asia
# 208           Asia
# 223         Europe
# 250  South America
# 251  North America
# 263         Africa

# %%
plt.scatter(life_exp["2020"],life_exp["Country Name"], color="cyan");

# %%
plt.scatter(gdp["2018"],gdp["Country Name"], color="blue");

# %%
plt.scatter(gini["2018"],gini["Country Name"], color="green");

# %%
plt.scatter(inflacao["2018"],inflacao["Country Name"], color="red");
